# %% [markdown]
# # Healthier Groceries Recommender
#
# ### Recommender

# %% [markdown]
# *In this notebook you will find:*
# 1. Healthier Groceries Recommender

# %% [markdown]
# ### Instructions for Use:
# 1. Execute All Cells
# 2. Input food interested in to "Enter Food Here" cell.
# 3. Of the foods listed, input the fdc-id for the food you want.
# 4. Healthier foods in that category will be output as a dataframe.  You will pick your healthier item from that dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final = pd.read_csv('Final_Nutrition.csv')

# %%
final.set_index('fdc_id', inplace=True, drop=False)

# %%
final.head()
# Out:
#         fdc_id        brand_owner  \
# fdc_id
# 356425  356425  G. T. Japan, Inc.
# 356426  356426  FRESH & EASY
# 356427  356427  FRESH & EASY
# 356428  356428  FRESH & EASY
# 356429  356429  FRESH & EASY
#
#                                                                                                                                                                                                                                                                                                                                                                                                   ingredients  \
# fdc_id
# 356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STRAWBERRIES (STRAWBERRIES, SUGAR), CORN SYRUP SOLIDS, SKIM MILK, WHEY, NATURAL FLAVOR, GUAR GUM, MONO & DIGLYCERIDES, BEET JUICE AND BEET POWDER (FOR COLOR), CELLULOSE GUM, LOCUST BEAN GUM, CARRAGEENAN. COATING INGREDIENTS: SUGAR, WATER, RICE FLOUR, TREHALOSE, EGG WHITES, BEET JUICE AND BEET POWDER (FOR COLOR), DUSTED WITH CORN & POTATO STARCH
# 356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLED VINEGAR, CONTAINS 2% OR LESS OF: CORN STARCH, SALT, DRIED CHIPOTLE PEPPER, NATURAL SMOKE FLAVOR, MUSTARD FLOUR, DRIED GARLIC, DRIED ONION, SPICES.
# 356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE, MOLASSES, MODIFIED CORN STARCH, SALT, PINEAPPLE JUICE CONCENTRATE, CONTAINS 1% OR LESS OF: JALAPENO PEPPERS, SPICE, CARAMEL COLOR, NATURAL FLAVOR, XANTHAN GUM, GARLIC POWDER, TAMARIND EXTRACT.
# 356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DISTILLED VINEGAR, MOLASSES, WATER, MODIFIED CORN STARCH, SALT, BOURBON WHISKEY, CONTAINS 1% OR LESS OF: MUSTARD FLOUR, SPICE, DRIED ONION, DRIED GARLIC, NATURAL FLAVOR, XANTHAN GUM, CARAMEL COLOR.
# 356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE, HONEY, MOLASSES, MODIFIED CORN STARCH, SALT, CONTAINS 1% OR LESS OF: NATURAL FLAVOR, PINEAPPLE JUICE CONCENTRATE, SPICE, CARAMEL COLOR, XANTHAN GUM, GARLIC POWDER, TAMARIND EXTRACT.
#
#         serving_size serving_size_unit                 branded_food_category  \
# fdc_id
# 356425  40.0          g                 Ice Cream & Frozen Yogurt
# 356426  37.0          g                 Ketchup, Mustard, BBQ & Cheese Sauce
# 356427  34.0          g                 Ketchup, Mustard, BBQ & Cheese Sauce
# 356428  35.0          g                 Ketchup, Mustard, BBQ & Cheese Sauce
# 356429  37.0          g                 Ketchup, Mustard, BBQ & Cheese Sauce
#
#            data_type                 description publication_date  cat_null  \
# fdc_id
# 356425  branded_food  MOCHI ICE CREAM BONBONS     2019-04-01       False
# 356426  branded_food  CHIPOTLE BARBECUE SAUCE     2019-04-01       False
# 356427  branded_food  HOT & SPICY BARBECUE SAUCE  2019-04-01       False
# 356428  branded_food  BARBECUE SAUCE              2019-04-01       False
# 356429  branded_food  BARBECUE SAUCE              2019-04-01       False
#
#            ...       fiber_grams  vitamin_a_IU  vitamin_c_MG  calcium_MG  \
# fdc_id     ...
# 356425     ...       0.0          0.000         0.050000      0.05
# 356426     ...       0.0          0.054         0.161667      0.00
# 356427     ...       0.0          0.000         0.000000      0.00
# 356428     ...       0.0          0.000         0.000000      0.00
# 356429     ...       0.0          0.000         0.000000      0.00
#
#         iron_MG  sugar_G  sodium_MG   NRFNn.3  cluster  new_cluster
# fdc_id
# 356425  0.0      0.24000  0.031250  -0.308750 NaN       1086.0
# 356426  0.0      0.30272  0.292917  -0.379970 NaN       1162.0
# 356427  0.0      0.28232  0.281667  -0.563987 NaN       1162.0
# 356428  0.0      0.22856  0.404583  -0.633143 NaN       1162.0
# 356429  0.0      0.34592  0.315417  -0.661337 NaN       1162.0
#
# [5 rows x 26 columns]

# %%
final.columns
# Out:
# Index(['fdc_id', 'brand_owner', 'ingredients', 'serving_size',
#        'serving_size_unit', 'branded_food_category', 'data_type',
#        'description', 'publication_date', 'cat_null', 'sat_fat_g',
#        'trans_fat_g', 'magnesium_mg', 'potassium_mg', 'mufa_grams',
#        'protein_grams', 'fiber_grams', 'vitamin_a_IU', 'vitamin_c_MG',
#        'calcium_MG', 'iron_MG', 'sugar_G', 'sodium_MG', 'NRFNn.3', 'cluster',
#        'new_cluster'],
#       dtype='object')

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.RED + 'Hello World !' + color.END)
# Out:
# Hello World !

# %%
q = input('Enter Food Here: ')
df = pd.DataFrame([])
print(final[final['description'].str.contains(q)]['description'])
inp = int(input('Choose Food Item: '))
cluster = final[final['cluster']==final['cluster'][inp]]
print(color.RED + color.BOLD + 
      f"Your original food selection was {final['description'][inp]} with a nutrition index of {final['NRFNn.3'][inp]:.2f}." + 
      color.END)
for i in cluster.index:
    if final['NRFNn.3'][i] > final['NRFNn.3'][inp]:
        df = df.append(pd.DataFrame({'ID': final['fdc_id'][i], 
                                     'Alternative Food Option': final['description'][i], 
                                     'Nutrition Index': final['NRFNn.3'][i], 
                                     'Protein %DV': final['protein_grams'][i]*100, 
                                     'Fiber %DV': final['fiber_grams'][i]*100, 
                                     'Monounsaturated Fat %DV': final['mufa_grams'][i]*100,
                                     'Vitamin A %DV': final['vitamin_a_IU'][i]*100, 
                                     'Vitamin C %DV': final['vitamin_c_MG'][i]*100, 
                                     'Calcium %DV': final['calcium_MG'][i]*100, 
                                     'Iron %DV': final['iron_MG'][i]*100, 
                                     'Potassium %DV': final['potassium_mg'][i]*100, 
                                     'Saturated Fat %DV': final['sat_fat_g'][i]*100, 
                                     'Trans Fat %DV': final['trans_fat_g'][i]*100, 
                                     'Sugar %DV': final['sugar_G'][i]*100, 
                                     'Sodium %DV': final['sodium_MG'][i]*100},
                                    index=[0]), ignore_index=True)
    else:
        pass
if df.empty:
    print("You selected the healthiest item!")
else:
    pd.set_option('display.max_colwidth', -1)
    df = df.round(2)
    df = df.sort_values(by='Nutrition Index', ascending=False)
    print(color.RED + color.BOLD + "Would you consider one of the following healthier options?" + color.END)
df.head()
# Out:
# Enter Food Here: Chocolate
# fdc_id
# 344636    Keebler Fudge Shoppe Cookies Chocolate Vanilla Creme 13.6oz
# 344652    Kellogg's Cereal Breakfast Bar Chocolate 1.34oz
# 344659    Keebler Other Cookies Chocolate Chip 13.3oz 12ct
# 344682    Keebler Sandies Cookies Dark Chocolate Almond 11.3oz
# 344701    Keebler Grahams Crackers Elf Chocolate 1oz
# 344705    Keebler Gripz Crackers Chocolate Chip .95oz
# 344738    Famous Amos Caddies Cookies Chocolate Chip 1.2oz
# 344739    Famous Amos Caddies Cookies Chocolate Chip 14.4oz
# 344808    Mother's Cookies Double Chocolate Chip 12oz
# 344810    Keebler Chips Deluxe Cookies Chocolate Chunk 11.6oz
# 344831    Keebler Premium Cookie Meal Chocolate 160oz 1ct
# 344833    Keebler Chips Deluxe Cookies Soft N Chewy Chocolate Chip 14.8oz
# 344842    Kellogg's Pop-Tarts Chocolate Chip 3.67oz
# 344845    Kellogg's Frosted Flakes Cereal Chocolate Multi Grain 1oz
# 344853    Kellogg's Pop-Tarts Chocolate Caramel 14.1oz
# 344870    Kellogg's Pop-Tarts Chocolate Chip Cookie Dough 14.1oz
# 344879    Kellogg's Pop-Tarts Chocolate Fudge 22oz
# 344884    Kellogg's Pop-Tarts Chocolate Fudge 29.3oz
# 344888    Kellogg's Pop-Tarts Chocolate Chip 29.3oz
# 344889    Kellogg's Pop-Tarts Chocolate Chip Cookie Dough 28.2oz
# 344897    Kellogg's Pop-Tarts Chocolate Fudge 29.3oz
# 344900    Kellogg's Pop-Tarts Chocolate Peanut Butter 10.5oz
# 344904    Kellogg's Pop-Tarts Chocolate Vanilla Creme 14.1oz
# 344905    Famous Amos Caddies Cookies Chocolate Chip 2.7oz
# 344906    Famous Amos Cookies Chocolate Chip 12.4oz
# 344907    Famous Amos Cookies Chocolate Chip 8oz
# 344930    Bear Naked Bars Double Chocolate 1.41oz
# 344952    Kashi Chewy Bars Cherry Dark Chocolate 1.2oz
# 344954    Kashi Crunchy Bars Chocolate Chip 1.4oz
# 344967    Kashi Golean Bars Salted Dark Chocolate & Nut Butter 1.59oz
#                                      ...
# 353086    Quaker Big Chewy Peanut Butter Chocolate Chip Granola Bar 1.48 Ounce Plastic Bag
# 353109    Quaker Rice Cakes Chocolate Crunch 7.23 Ounce Plastic Bag
# 353252    Gamesa Sugarwafer Chocolate Cookie 6.7 Ounce Plastic Bag
# 353373    Quaker Chewy Dipps Peanut Butter Chocolate Chip (12-0.84 Oz) 10.1 Ounce 12 Pack Bag in Box
# 353495    Gatorade Recover Whey Protein Bar Chocolate Chip 2.8 Ounce Plastic Bag
