# %% [markdown]
# # Healthier Groceries Recommender
#
# ### Recommender

# %% [markdown]
# *In this notebook you will find:*
# 1. Healthier Groceries Recommender

# %% [markdown]
# ### Instructions for Use:
# 1. Execute All Cells
# 2. Input food interested in to "Enter Food Here" cell.
# 3. Of the foods listed, input the fdc-id for the food you want.
# 4. Healthier foods in that category will be output as a dataframe.  You will pick your healthier item from that dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final = pd.read_csv('Final_Nutrition.csv')

# %%
final.set_index('fdc_id', inplace=True, drop=False)

# %%
final.head()
# Out:
#         fdc_id        brand_owner  \
# fdc_id
# 356425  356425  G. T. Japan, Inc.
# 356426  356426       FRESH & EASY
# 356427  356427       FRESH & EASY
# 356428  356428       FRESH & EASY
# 356429  356429       FRESH & EASY
#
#                                               ingredients  serving_size  \
# fdc_id
# 356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...          40.0
# 356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...          37.0
# 356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...          34.0
# 356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...          35.0
# 356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...          37.0
#
#        serving_size_unit                 branded_food_category     data_type  \
# fdc_id
# 356425                 g             Ice Cream & Frozen Yogurt  branded_food
# 356426                 g  Ketchup, Mustard, BBQ & Cheese Sauce  branded_food
# ...

# %%
final.columns
# Out:
# Index(['fdc_id', 'brand_owner', 'ingredients', 'serving_size',
#        'serving_size_unit', 'branded_food_category', 'data_type',
#        'description', 'publication_date', 'cat_null', 'sat_fat_g',
#        'trans_fat_g', 'magnesium_mg', 'potassium_mg', 'mufa_grams',
#        'protein_grams', 'fiber_grams', 'vitamin_a_IU', 'vitamin_c_MG',
#        'calcium_MG', 'iron_MG', 'sugar_G', 'sodium_MG', 'NRFNn.3', 'cluster',
#        'new_cluster'],
#       dtype='object')

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.RED + 'Hello World !' + color.END)
# Out:
# Hello World !

# %%
q = input('Enter Food Here: ')
df = pd.DataFrame([])
print(final[final['description'].str.contains(q)]['description'])
inp = int(input('Choose Food Item: '))
cluster = final[final['new_cluster']==final['new_cluster'][inp]]
print(color.RED + color.BOLD + 
      f"Your original food selection was {final['description'][inp]} with a nutrition index of {final['NRFNn.3'][inp]:.2f}." + 
      color.END)
for i in cluster.index:
    if final['NRFNn.3'][i] > final['NRFNn.3'][inp]:
        df = df.append(pd.DataFrame({'ID': final['fdc_id'][i], 
                                     'Alternative Food Option': final['description'][i], 
                                     'Nutrition Index': final['NRFNn.3'][i], 
                                     'Protein %DV': final['protein_grams'][i]*100, 
                                     'Fiber %DV': final['fiber_grams'][i]*100, 
                                     'Monounsaturated Fat %DV': final['mufa_grams'][i]*100,
                                     'Vitamin A %DV': final['vitamin_a_IU'][i]*100, 
                                     'Vitamin C %DV': final['vitamin_c_MG'][i]*100, 
                                     'Calcium %DV': final['calcium_MG'][i]*100, 
                                     'Iron %DV': final['iron_MG'][i]*100, 
                                     'Potassium %DV': final['potassium_mg'][i]*100, 
                                     'Saturated Fat %DV': final['sat_fat_g'][i]*100, 
                                     'Trans Fat %DV': final['trans_fat_g'][i]*100, 
                                     'Sugar %DV': final['sugar_G'][i]*100, 
                                     'Sodium %DV': final['sodium_MG'][i]*100},
                                    index=[0]), ignore_index=True)
    else:
        pass
if df.empty:
    print("You selected the healthiest item!")
else:
    pd.set_option('display.max_colwidth', -1)
    df = df.round(2)
    df = df.sort_values(by='Nutrition Index', ascending=False)
    print(color.RED + color.BOLD + "Would you consider one of the following healthier options?" + color.END)
df
# Out:
# Enter Food Here: ICE CREAM
# fdc_id
# 356425    MOCHI ICE CREAM BONBONS
# 356444    FINE ICE CREAMS
# 356469    VANILLA BEAN ICE CREAM
# 356470    LIGHT ICE CREAM
# 356471    ICE CREAM
# 356476    ICE CREAM, GELATO
# 356845    ALBERTSON'S, SEA SALTED CARAMEL SWIRL ICE CREAM
# 356848    ICE CREAM
# 356849    ALBERTSON'S, ICE CREAM, ROCKY ROAD, CHOCOLATE ICE CREAM WITH MARSHMALLOW RIBBON AND MIXED NUTS
# 356850    ALBERTSON'S, ICE CREAM, CHOCOLATE
# 356851    ICE CREAM
# 356852    ALBERTSON'S, ICE CREAM, MINT CHIP
# 356853    ALBERTSON'S, NEOPOLITAN ICE CREAM
# 356854    ALBERTSON'S, ICE CREAM, BUTTER PECAN
# 356855    ALBERTSON'S, RICH & CREAMY ICE CREAM, FRENCH VANILLA
# 357109    THREE TWINS ICE CREAM, ORGANIC ICE CREAM, MINT CONFETTI, MINT CONFETTI
# 357123    ORGANIC ICE CREAM
# 357124    ORGANIC ICE CREAM
# 357125    JULIE'S, ORGANIC VANILLA ICE CREAM SANDWICH
# 357126    JULIE'S, ORGANIC CHOCOLATE ICE CREAM BAR, CHOCOLATE
# ...

# %%
df.set_index('ID', inplace=True, drop=False)

# %%
df.loc[[602515, 569414, 545251, 408615, 546233, 601577, 397160, 603089]]
# Out:
#             ID                                     Alternative Food Option  \
# ID
# 602515  602515  SCANDAL-LESS CHOCOLATE LOW FAT ICE CREAM BAR, CHOCOLATE
# 569414  569414  LOW FAT CHOCOLATE ICE CREAM
# 545251  545251  GIANT CHOCOLATE FUDGE ICE CREAM BARS
# 408615  408615  DELUXE CHURNED ICE CREAM
# 546233  546233  BREYERS, DELIGHTS, LOW FAT ICE CREAM, CREAMY CHOCOLATE
# 601577  601577  CHOCOLATE LIGHT ICE CREAM, CHOCOLATE
# 397160  397160  BREYERS, FAT FREE ICE CREAM, CHOCOLATE
# 603089  603089  LIGHT DOUBLE FUDGE BROWNIE ICE CREAM, DOUBLE FUDGE BROWNIE
#
#         Nutrition Index  Protein %DV  Fiber %DV  Monounsaturated Fat %DV  \
# ID
# 602515  0.62             23.34        6.8        0.0
# 569414  0.61             18.46        24.8       0.0
# 545251  0.51             8.82         29.6       0.0
# 408615  0.38             12.50        6.4        0.0
# 546233  0.33             15.56        4.4        0.0
# 601577  0.24             15.90        9.2        0.0
# ...

# %%
df[500:590]
# Out:
#           ID  \
# 3331  595237
# 348   390713
# 3427  602750
# 3425  602748
# 1432  457481
# 2385  529843
# 986   448829
# 3336  595242
# 1434  457498
# 1901  502300
# 1756  488360
# 3426  602749
# 836   436532
# 3044  574502
# 3132  580306
# 1192  452279
# 1869  501940
# 3234  586974
# 2986  572183
# 2042  512169
# 122   368204
# 3123  578992
# 1645  478265
# 2931  570259
# 1978  507046
# 656   405417
# 1486  469120
# 1684  481398
# 541   397160
# 362   390737
# ...      ...
# 559   398832
# 503   397101
# 2310  527517
# 2626  543539
# 2305  527438
# 2907  568122
# 1912  502456
# 3433  603089
# 1900  502284
# 2246  525747
# 2791  558221
# 143   368303
# 1777  489150
# 1650  479083
# 3130  580304
# 3430  602753
# 2753  555560
# 2037  512133
# 2424  531881
# 3054  574771
# 3122  578901
# 1511  469586
# 3214  585958
# 1641  478258
# 1908  502435
# 2615  542717
# 1608  477357
# 2151  521793
# 260   379864
# 850   437544
#
# ...

# %%
for i in df['Alternative Food Option']:
    print(i)
# Out:
# SLTEST_DISCONTINUED_USI_NESTLE POPPIN' POPS
# THRIVE, REAL ICE CREAM, CHOCOLATE
# ICE CREAM
# ALL-NATURAL FROZEN GREEK YOGURT BREAKFAST BAR
# SORBET POPS
# GLOW POPS
# BRIO, FROZEN DAIRY DESSERT, TROPICAL MANGO
# GARDEN POPS
# SORBET POPS
# SORBET POPS
# THRIVE, REAL ICE CREAM, CHOCOLATE
# REAL ICE CREAM
# THRIVE, REAL ICE CREAM, CREAMY VANILLA
# VEGGIE & FRUIT POPS
# SORBET POPS!
# PREMIUM ICE CREAM
# DIET SORBET BARS
# SPECIALTY BREWED BARS
# THRIVE, REAL ICE CREAM, SALTED CARAMEL
# FRUIT & VEGGIE BARS
# FRUIT & VEGGIE JUICE BARS
# POPS
# VEGGIE & FRUIT POPS
# ACTIVATE POPS
# FRUIT BARS
# ORANGE-PEACH FRUIT & VEGGIE BARS
# JUNIOR POPS
# ICE POPS
# RED WHITE & BLUE POPS
# RED, WHITE & BLUE POPS
# JUNIOR POPS
# GRAPE, ORGANIC & CHERRY ICE POPS
# ICE POPS
# ASSORTED JUNIOR POPS
# PARTY POPS
# ICE POPS
# ASSORTED JUNIOR POPS
# JUNIOR POPS
# ASSORTED JUNIOR ICE POPS
# JUICE STIX
# BANANA POPS
# RAINBOW POPS
# JUNIOR ICE POPS
# POMEGRANATE RASPBERRY RIP
# PARTY POPS
# BEVERAGE
# ...

# %%
final.head()
# Out:
#         fdc_id        brand_owner  \
# fdc_id
# 356425  356425  G. T. Japan, Inc.
# 356426  356426  FRESH & EASY
# 356427  356427  FRESH & EASY
# 356428  356428  FRESH & EASY
# 356429  356429  FRESH & EASY
#
#                                                                                                                                                                                                                                                                                                                                                                                                   ingredients  \
# fdc_id
# ...

# %%
test = final[final['branded_food_category']=='Ice Cream & Frozen Yogurt']

# %%
test
# Out:
#         fdc_id                   brand_owner  \
# fdc_id
# 356425  356425  G. T. Japan, Inc.
# 356444  356444  McConnell's Ice Cream Inc.
# 356469  356469  FRESH & EASY
# 356470  356470  FRESH & EASY
# 356471  356471  FRESH & EASY
# 356472  356472  FRESH & EASY
# 356473  356473  FRESH & EASY
# 356474  356474  FRESH & EASY
# 356475  356475  FRESH & EASY
# 356476  356476  FRESH&EASY
# 356477  356477  FRESH & EASY
# 356478  356478  FRESH & EASY
# 356845  356845  Supervalu, Inc.
# 356846  356846  Supervalu, Inc.
# 356847  356847  Supervalu, Inc.
# 356848  356848  Supervalu, Inc.
# 356849  356849  Supervalu, Inc.
# 356850  356850  Supervalu, Inc.
# 356851  356851  Supervalu, Inc.
# 356852  356852  Supervalu, Inc.
# 356853  356853  Supervalu, Inc.
# 356854  356854  Supervalu, Inc.
# 356855  356855  Supervalu, Inc.
# 357109  357109  Quisling Media
# 357123  357123  Ad-Visor
# 357124  357124  Jdh Distribution Inc.
# 357125  357125  Oregon Ice Cream, LLC
# ...

# %%
for i in test['description']:
    print(i)
# Out:
# MOCHI ICE CREAM BONBONS
# FINE ICE CREAMS
# VANILLA BEAN ICE CREAM
# LIGHT ICE CREAM
# ICE CREAM
# SORBET
# SORBET
# BLOOD ORANGE SORBET
# GELATO
# ICE CREAM, GELATO
# GELATO
# GELATO
# ALBERTSON'S, SEA SALTED CARAMEL SWIRL ICE CREAM
# GREEK FROZEN YOGURT
# ALBERTSON'S, GREEK FROZEN YOGURT, BLACK RASPBERRY
# ICE CREAM
# ALBERTSON'S, ICE CREAM, ROCKY ROAD, CHOCOLATE ICE CREAM WITH MARSHMALLOW RIBBON AND MIXED NUTS
# ALBERTSON'S, ICE CREAM, CHOCOLATE
# ICE CREAM
# ALBERTSON'S, ICE CREAM, MINT CHIP
# ALBERTSON'S, NEOPOLITAN ICE CREAM
# ALBERTSON'S, ICE CREAM, BUTTER PECAN
# ALBERTSON'S, RICH & CREAMY ICE CREAM, FRENCH VANILLA
# THREE TWINS ICE CREAM, ORGANIC ICE CREAM, MINT CONFETTI, MINT CONFETTI
# ORGANIC ICE CREAM
# ORGANIC ICE CREAM
# JULIE'S, ORGANIC VANILLA ICE CREAM SANDWICH
# JULIE'S, ORGANIC CHOCOLATE ICE CREAM BAR, CHOCOLATE
# SORBETTO
# ALDEN'S, ORGANIC SHERBET, ORANGE
# ALDEN'S, ORGANIC LIGHT ICE CREAM, VANILLA
# ALDEN'S, ORGANIC ICE CREAM, PEACHES 'N CREAM
# ...
